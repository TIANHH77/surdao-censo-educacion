# %%
import pandas as pd

# Cargar la super-tabla
ruta = r"C:\PROYECTOS\Agente_Alura\data\dataset_auditoria_final.parquet"
df_auditoria = pd.read_parquet(ruta)

# 1. Listar todas las columnas para buscar la llave geográfica
print("Todas las columnas:")
print(df_auditoria.columns.tolist())

# 2. Mostrar las primeras 3 filas (Jupyter las va a renderizar hermoso)
df_auditoria.head(3)
# Out:
# Todas las columnas:
# ['RBD', 'Nombre_Colegio', 'Total_Alumnos', 'Total_Docentes', 'Ratio_Alumnos_Docente', 'Promedio_Notas', 'Anio', 'LATITUD', 'LONGITUD', 'CUT', 'COD_REGION', 'REGION', 'COD_PROVINCIA', 'PROVINCIA', 'COMUNA', 'Volatilidad_Rendimiento']
#      RBD                 Nombre_Colegio  Total_Alumnos  Total_Docentes  \
# 0  40311             COLEGIO CAUPOLICAN            181             1.0
# 1   3012            COLEGIO DE LA SALLE            749             8.0
# 2  25045  COLEGIO PARTICULAR PLAYGROUND            231             4.0
#
#    Ratio_Alumnos_Docente  Promedio_Notas  Anio    LATITUD   LONGITUD    CUT  \
# 0                  181.0            5.67  2012 -53.295397 -70.354744  12301
# 1                   93.6            6.19  2012 -35.422942 -71.665370   7101
# 2                   57.8            6.13  2012 -33.522054 -70.566570  13110
#
#    COD_REGION                                REGION  COD_PROVINCIA  \
# ...

# %%
import os

ruta_data = r"C:\PROYECTOS\Agente_Alura\data"

# Filtramos solo los archivos parquet
archivos_parquet = [f for f in os.listdir(ruta_data) if f.endswith('.parquet')]

print("🔑 LLAVES EXACTAS PARA EL DICCIONARIO dfs:")
print("-" * 50)
for archivo in archivos_parquet:
    # Asumimos que tu app quita la extensión '.parquet' para nombrar la llave
    llave = archivo.replace('.parquet', '')
    print(f'"{llave}"')
# Out:
# 🔑 LLAVES EXACTAS PARA EL DICCIONARIO dfs:
# --------------------------------------------------
# "D1_1_Población_censada_por_sexo_y_razón_hombre-mujer_según_regi"
# "D1_2_Población_censada_por_sexo_y_razón_hombre-mujer_según_comu"
# "D1_3_Población_censada_por_sexo_y_razón_hombre-mujer_según_grup"
# "D1_4_Población_censada_por_sexo_y_razón_hombre-mujer_según_grup"
# "D2_1_Población_censada_por_tramo_de_edad_e_índice_de_envejecimi"
# "D2_2_Población_censada_por_tramo_de_edad_e_índice_de_envejecimi"
# "D3_1_Población_censada_por_tipo_de_operativo_según_región"
# "D4_1_Inmigrantes_internacionales_por_sexo_según_región"
# "D4_2_Inmigrantes_internacionales_por_grupos_de_edad_según_regió"
# "D4_3_Inmigrantes_internacionales_por_país_de_nacimiento_según_r"
# "D4_4_Inmigrantes_internacionales_por_país_de_nacimiento_según_c"
# "D4_5_Inmigrantes_internacionales_por_periodo_de_llegada_a_Chile"
# "D5_1_Población_censada_por_región_de_residencia_habitual_hace_5"
# ...
